# %%
import os
import pickle
import gc

import numpy as np
import pandas as pd

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.regularizers import L1L2

from sklearn.model_selection import train_test_split

# %%
MODEL = "7-auto-regressive-lstm-covariates-future-only"
COVARIATE_COLUMNS = ['covs_week_sin','covs_week_cos','covs_day_sin','covs_day_cos','covs_hour_sin','covs_hour_cos','covs_rbf_month_1','covs_rbf_month_2','covs_rbf_month_3','covs_rbf_month_4','covs_rbf_month_5','covs_rbf_month_6','covs_rbf_month_7','covs_rbf_month_8','covs_rbf_month_9','covs_rbf_month_10','covs_rbf_month_11','covs_rbf_month_12']

config = {
    "N_PREV": 120,
    "N_FORWARD": 48,
    "STEP_SIZE": 1,
    
    "LATENT_SIZE": 16,
    
    "LR": 0.001,
    "BATCH_SIZE": 256,
    "EPOCHS": 2,
    
    "L1": 0.0000001, 
    "L2": 0.0000001,
    
    "TARGET_COL": 'normalized_level',
}

# %%
import wandb
from wandb.keras import WandbCallback
from secrets import WANDB
wandb.login(key=WANDB)
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\KiernanMcGuigan/.netrc
# True

# %% [markdown]
# ## **Load Data Function**

# %%
def get_samples(df, set_number):
    subset = df.loc[df.set==set_number, :]
    shape = subset.shape
    if(shape[0] > 1_000):
        subset = subset.iloc[-1_000:, :]
    data = subset[config['TARGET_COL']].values
    covariates = subset[COVARIATE_COLUMNS].values
    print(f'Data Shape: {shape}, Reduced Shape {data.shape}')
    
    X, y, future_covs, dates = [], [], [], []
    for start_idx in range(0, data.shape[0]-config["N_PREV"]-config["N_FORWARD"], config["STEP_SIZE"]):
        mid_idx = start_idx + config["N_PREV"]
        end_idx = mid_idx + config["N_FORWARD"]
        X.append(data[start_idx:mid_idx])
        y.append(data[mid_idx:end_idx])
        future_covs.append(covariates[mid_idx:end_idx])
        dates.append(subset.iloc[mid_idx:end_idx].index.values)
    return np.array(X), np.array(y), np.array(future_covs), np.array(dates)

def to_dataset(X1, X2, y):
    dataset = tf.data.Dataset.from_tensor_slices(({'series':X1, 'future_dates':X2}, y))
    dataset = dataset.cache().shuffle(X1.shape[0]+1).batch(config["BATCH_SIZE"]).prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

def get_train_and_val_datasets(X1, X2, y):
    X1_train, X1_val, X2_train, X2_val, y_train, y_val = train_test_split(X1, X2, y, test_size=0.15, shuffle=True)
    train_ds = to_dataset(X1_train, X2_train, y_train)
    val_ds = to_dataset(X1_val, X2_val, y_val)
    return train_ds, val_ds

def df_to_samples(df):
    X, y, future, _ = get_samples(df, 0)
    train_ds, val_ds = get_train_and_val_datasets(X, future, y)
    X_test, y_test, future_test, dates = get_samples(df, 1)
    return train_ds, val_ds, X_test, y_test, future_test, dates
    
def get_data(fold):
    df = pd.read_csv(f'data/fold{fold}_data_v3.csv')
    with open(f'./data/fold{fold}_normalizer_v3.pkl', mode='rb') as f:
        normalizer = pickle.load(f)
    return df_to_samples(df), normalizer

# %% [markdown]
# ## **Model Functions**

# %%
def get_model():
    inputs = tf.keras.layers.Input(shape=(config["N_PREV"], 1), name='series')
    future_covs = tf.keras.layers.Input(shape=(config["N_FORWARD"], len(COVARIATE_COLUMNS)), name='future_dates')
    
    lstm1 = tf.keras.layers.LSTM(config["LATENT_SIZE"], 
                                 return_sequences=True, 
                                 return_state=True, 
                                 recurrent_initializer='glorot_uniform', 
                                 activity_regularizer=L1L2(l1=config['L1'],l2=config['L2']))
    lstm2 = tf.keras.layers.LSTM(config["LATENT_SIZE"], 
                                 return_sequences=True, 
                                 return_state=True, 
                                 recurrent_initializer='glorot_uniform', 
                                 activity_regularizer=L1L2(l1=config['L1'],l2=config['L2']))
    lstm3 = tf.keras.layers.LSTM(config["LATENT_SIZE"], 
                                 return_sequences=False, 
                                 return_state=True, 
                                 recurrent_initializer='glorot_uniform', 
                                 activity_regularizer=L1L2(l1=config['L1'],l2=config['L2']))
    dense1 = tf.keras.layers.Dense(16)
    dense2 = tf.keras.layers.Dense(8)
    dense3 = tf.keras.layers.Dense(1)
    
    predictions = []
    x, hidden_state1, cell_state1 = lstm1(inputs)
    x, hidden_state2, cell_state2 = lstm2(x)
    x, hidden_state3, cell_state3 = lstm3(x)
    x = K.concatenate([x, future_covs[:, 0, :]])
    x = dense1(x)
    x = dense2(x)
    x = dense3(x)
    
    predictions.append(x)
    for idx in range(1, config['N_FORWARD']):
        x = tf.expand_dims(x, axis=1)
        x, hidden_state1, cell_state1 = lstm1(x, initial_state=[hidden_state1, cell_state1])
        x, hidden_state2, cell_state2 = lstm2(x, initial_state=[hidden_state2, cell_state2])
        x, hidden_state3, cell_state3 = lstm3(x, initial_state=[hidden_state3, cell_state3])
        x = K.concatenate([x, future_covs[:, idx, :]])
        x = dense1(x)
        x = dense2(x)
        x = dense3(x)
        
        predictions.append(x)
        
    outputs = tf.keras.layers.Lambda(lambda x: K.concatenate(x, axis=1))(predictions)
    model = tf.keras.models.Model(inputs=[inputs,future_covs], outputs=outputs)
    model.compile(loss="mse", metrics=["mae"], optimizer=tf.keras.optimizers.Adam(learning_rate=config["LR"]))
    return model

# def get_model():
#     model = MyModel()
#     model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(config["LR"]), metrics=['mae'])
#     model.predict(tf.ones(shape=(config['BATCH_SIZE'],config['N_PREV'],1)))
#     return model
    
test_model = get_model()
print(test_model.summary())
del test_model
gc.collect()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  series (InputLayer)            [(None, 120, 1)]     0           []
#
#  lstm_6 (LSTM)                  multiple             1152        ['series[0][0]',
#                                                                   'tf.expand_dims_47[0][0]',
#                                                                   'lstm_6[0][1]',
#                                                                   'lstm_6[0][2]',
#                                                                   'tf.expand_dims_48[0][0]',
#                                                                   'lstm_6[1][1]',
#                                                                   'lstm_6[1][2]',
#                                                                   'tf.expand_dims_49[0][0]',
#                                                                   'lstm_6[2][1]',
#                                                                   'lstm_6[2][2]',
#                                                                   'tf.expand_dims_50[0][0]',
#                                                                   'lstm_6[3][1]',
#                                                                   'lstm_6[3][2]',
#                                                                   'tf.expand_dims_51[0][0]',
#                                                                   'lstm_6[4][1]',
#                                                                   'lstm_6[4][2]',
#                                                                   'tf.expand_dims_52[0][0]',
#                                                                   'lstm_6[5][1]',
#                                                                   'lstm_6[5][2]',
#                                                                   'tf.expand_dims_53[0][0]',
#                                                                   'lstm_6[6][1]',
#                                                                   'lstm_6[6][2]',
#                                                                   'tf.expand_dims_54[0][0]',
#                                                                   'lstm_6[7][1]',
#                                                                   'lstm_6[7][2]',
#                                                                   'tf.expand_dims_55[0][0]',
#                                                                   'lstm_6[8][1]',
#                                                                   'lstm_6[8][2]',
#                                                                   'tf.expand_dims_56[0][0]',
#                                                                   'lstm_6[9][1]',
#                                                                   'lstm_6[9][2]',
#                                                                   'tf.expand_dims_57[0][0]',
#                                                                   'lstm_6[10][1]',
#                                                                   'lstm_6[10][2]',
#                                                                   'tf.expand_dims_58[0][0]',
#                                                                   'lstm_6[11][1]',
#                                                                   'lstm_6[11][2]',
#                                                                   'tf.expand_dims_59[0][0]',
#                                                                   'lstm_6[12][1]',
#                                                                   'lstm_6[12][2]',
#                                                                   'tf.expand_dims_60[0][0]',
#                                                                   'lstm_6[13][1]',
#                                                                   'lstm_6[13][2]',
#                                                                   'tf.expand_dims_61[0][0]',
#                                                                   'lstm_6[14][1]',
#                                                                   'lstm_6[14][2]',
#                                                                   'tf.expand_dims_62[0][0]',
#                                                                   'lstm_6[15][1]',
#                                                                   'lstm_6[15][2]',
#                                                                   'tf.expand_dims_63[0][0]',
#                                                                   'lstm_6[16][1]',
#                                                                   'lstm_6[16][2]',
#                                                                   'tf.expand_dims_64[0][0]',
#                                                                   'lstm_6[17][1]',
#                                                                   'lstm_6[17][2]',
#                                                                   'tf.expand_dims_65[0][0]',
#                                                                   'lstm_6[18][1]',
#                                                                   'lstm_6[18][2]',
#                                                                   'tf.expand_dims_66[0][0]',
#                                                                   'lstm_6[19][1]',
#                                                                   'lstm_6[19][2]',
#                                                                   'tf.expand_dims_67[0][0]',
#                                                                   'lstm_6[20][1]',
#                                                                   'lstm_6[20][2]',
#                                                                   'tf.expand_dims_68[0][0]',
#                                                                   'lstm_6[21][1]',
#                                                                   'lstm_6[21][2]',
#                                                                   'tf.expand_dims_69[0][0]',
#                                                                   'lstm_6[22][1]',
#                                                                   'lstm_6[22][2]',
#                                                                   'tf.expand_dims_70[0][0]',
#                                                                   'lstm_6[23][1]',
#                                                                   'lstm_6[23][2]',
#                                                                   'tf.expand_dims_71[0][0]',
#                                                                   'lstm_6[24][1]',
#                                                                   'lstm_6[24][2]',
#                                                                   'tf.expand_dims_72[0][0]',
#                                                                   'lstm_6[25][1]',
#                                                                   'lstm_6[25][2]',
#                                                                   'tf.expand_dims_73[0][0]',
#                                                                   'lstm_6[26][1]',
#                                                                   'lstm_6[26][2]',
#                                                                   'tf.expand_dims_74[0][0]',
#                                                                   'lstm_6[27][1]',
#                                                                   'lstm_6[27][2]',
#                                                                   'tf.expand_dims_75[0][0]',
#                                                                   'lstm_6[28][1]',
#                                                                   'lstm_6[28][2]',
#                                                                   'tf.expand_dims_76[0][0]',
#                                                                   'lstm_6[29][1]',
#                                                                   'lstm_6[29][2]',
#                                                                   'tf.expand_dims_77[0][0]',
#                                                                   'lstm_6[30][1]',
#                                                                   'lstm_6[30][2]',
#                                                                   'tf.expand_dims_78[0][0]',
#                                                                   'lstm_6[31][1]',
#                                                                   'lstm_6[31][2]',
#                                                                   'tf.expand_dims_79[0][0]',
#                                                                   'lstm_6[32][1]',
#                                                                   'lstm_6[32][2]',
#                                                                   'tf.expand_dims_80[0][0]',
#                                                                   'lstm_6[33][1]',
#                                                                   'lstm_6[33][2]',
#                                                                   'tf.expand_dims_81[0][0]',
#                                                                   'lstm_6[34][1]',
#                                                                   'lstm_6[34][2]',
#                                                                   'tf.expand_dims_82[0][0]',
#                                                                   'lstm_6[35][1]',
#                                                                   'lstm_6[35][2]',
#                                                                   'tf.expand_dims_83[0][0]',
#                                                                   'lstm_6[36][1]',
#                                                                   'lstm_6[36][2]',
#                                                                   'tf.expand_dims_84[0][0]',
#                                                                   'lstm_6[37][1]',
#                                                                   'lstm_6[37][2]',
#                                                                   'tf.expand_dims_85[0][0]',
#                                                                   'lstm_6[38][1]',
#                                                                   'lstm_6[38][2]',
#                                                                   'tf.expand_dims_86[0][0]',
#                                                                   'lstm_6[39][1]',
#                                                                   'lstm_6[39][2]',
#                                                                   'tf.expand_dims_87[0][0]',
#                                                                   'lstm_6[40][1]',
#                                                                   'lstm_6[40][2]',
#                                                                   'tf.expand_dims_88[0][0]',
#                                                                   'lstm_6[41][1]',
#                                                                   'lstm_6[41][2]',
#                                                                   'tf.expand_dims_89[0][0]',
#                                                                   'lstm_6[42][1]',
#                                                                   'lstm_6[42][2]',
#                                                                   'tf.expand_dims_90[0][0]',
#                                                                   'lstm_6[43][1]',
#                                                                   'lstm_6[43][2]',
#                                                                   'tf.expand_dims_91[0][0]',
#                                                                   'lstm_6[44][1]',
#                                                                   'lstm_6[44][2]',
#                                                                   'tf.expand_dims_92[0][0]',
#                                                                   'lstm_6[45][1]',
#                                                                   'lstm_6[45][2]',
#                                                                   'tf.expand_dims_93[0][0]',
#                                                                   'lstm_6[46][1]',
#                                                                   'lstm_6[46][2]']
#
#  lstm_7 (LSTM)                  multiple             2112        ['lstm_6[0][0]',
#                                                                   'lstm_6[1][0]',
#                                                                   'lstm_7[0][1]',
#                                                                   'lstm_7[0][2]',
#                                                                   'lstm_6[2][0]',
#                                                                   'lstm_7[1][1]',
#                                                                   'lstm_7[1][2]',
#                                                                   'lstm_6[3][0]',
#                                                                   'lstm_7[2][1]',
#                                                                   'lstm_7[2][2]',
#                                                                   'lstm_6[4][0]',
#                                                                   'lstm_7[3][1]',
#                                                                   'lstm_7[3][2]',
#                                                                   'lstm_6[5][0]',
#                                                                   'lstm_7[4][1]',
#                                                                   'lstm_7[4][2]',
#                                                                   'lstm_6[6][0]',
#                                                                   'lstm_7[5][1]',
#                                                                   'lstm_7[5][2]',
#                                                                   'lstm_6[7][0]',
#                                                                   'lstm_7[6][1]',
#                                                                   'lstm_7[6][2]',
#                                                                   'lstm_6[8][0]',
#                                                                   'lstm_7[7][1]',
#                                                                   'lstm_7[7][2]',
#                                                                   'lstm_6[9][0]',
#                                                                   'lstm_7[8][1]',
#                                                                   'lstm_7[8][2]',
#                                                                   'lstm_6[10][0]',
#                                                                   'lstm_7[9][1]',
#                                                                   'lstm_7[9][2]',
#                                                                   'lstm_6[11][0]',
#                                                                   'lstm_7[10][1]',
#                                                                   'lstm_7[10][2]',
#                                                                   'lstm_6[12][0]',
#                                                                   'lstm_7[11][1]',
#                                                                   'lstm_7[11][2]',
#                                                                   'lstm_6[13][0]',
#                                                                   'lstm_7[12][1]',
#                                                                   'lstm_7[12][2]',
#                                                                   'lstm_6[14][0]',
#                                                                   'lstm_7[13][1]',
#                                                                   'lstm_7[13][2]',
#                                                                   'lstm_6[15][0]',
#                                                                   'lstm_7[14][1]',
#                                                                   'lstm_7[14][2]',
#                                                                   'lstm_6[16][0]',
#                                                                   'lstm_7[15][1]',
#                                                                   'lstm_7[15][2]',
#                                                                   'lstm_6[17][0]',
#                                                                   'lstm_7[16][1]',
#                                                                   'lstm_7[16][2]',
#                                                                   'lstm_6[18][0]',
#                                                                   'lstm_7[17][1]',
#                                                                   'lstm_7[17][2]',
#                                                                   'lstm_6[19][0]',
#                                                                   'lstm_7[18][1]',
#                                                                   'lstm_7[18][2]',
#                                                                   'lstm_6[20][0]',
#                                                                   'lstm_7[19][1]',
#                                                                   'lstm_7[19][2]',
#                                                                   'lstm_6[21][0]',
#                                                                   'lstm_7[20][1]',
#                                                                   'lstm_7[20][2]',
#                                                                   'lstm_6[22][0]',
#                                                                   'lstm_7[21][1]',
#                                                                   'lstm_7[21][2]',
#                                                                   'lstm_6[23][0]',
#                                                                   'lstm_7[22][1]',
#                                                                   'lstm_7[22][2]',
#                                                                   'lstm_6[24][0]',
#                                                                   'lstm_7[23][1]',
#                                                                   'lstm_7[23][2]',
#                                                                   'lstm_6[25][0]',
#                                                                   'lstm_7[24][1]',
#                                                                   'lstm_7[24][2]',
#                                                                   'lstm_6[26][0]',
#                                                                   'lstm_7[25][1]',
#                                                                   'lstm_7[25][2]',
#                                                                   'lstm_6[27][0]',
#                                                                   'lstm_7[26][1]',
#                                                                   'lstm_7[26][2]',
#                                                                   'lstm_6[28][0]',
#                                                                   'lstm_7[27][1]',
#                                                                   'lstm_7[27][2]',
#                                                                   'lstm_6[29][0]',
#                                                                   'lstm_7[28][1]',
#                                                                   'lstm_7[28][2]',
#                                                                   'lstm_6[30][0]',
#                                                                   'lstm_7[29][1]',
#                                                                   'lstm_7[29][2]',
#                                                                   'lstm_6[31][0]',
#                                                                   'lstm_7[30][1]',
#                                                                   'lstm_7[30][2]',
#                                                                   'lstm_6[32][0]',
#                                                                   'lstm_7[31][1]',
#                                                                   'lstm_7[31][2]',
#                                                                   'lstm_6[33][0]',
#                                                                   'lstm_7[32][1]',
#                                                                   'lstm_7[32][2]',
#                                                                   'lstm_6[34][0]',
#                                                                   'lstm_7[33][1]',
#                                                                   'lstm_7[33][2]',
#                                                                   'lstm_6[35][0]',
#                                                                   'lstm_7[34][1]',
#                                                                   'lstm_7[34][2]',
#                                                                   'lstm_6[36][0]',
#                                                                   'lstm_7[35][1]',
#                                                                   'lstm_7[35][2]',
#                                                                   'lstm_6[37][0]',
#                                                                   'lstm_7[36][1]',
#                                                                   'lstm_7[36][2]',
#                                                                   'lstm_6[38][0]',
#                                                                   'lstm_7[37][1]',
#                                                                   'lstm_7[37][2]',
#                                                                   'lstm_6[39][0]',
#                                                                   'lstm_7[38][1]',
#                                                                   'lstm_7[38][2]',
#                                                                   'lstm_6[40][0]',
#                                                                   'lstm_7[39][1]',
#                                                                   'lstm_7[39][2]',
#                                                                   'lstm_6[41][0]',
#                                                                   'lstm_7[40][1]',
#                                                                   'lstm_7[40][2]',
#                                                                   'lstm_6[42][0]',
#                                                                   'lstm_7[41][1]',
#                                                                   'lstm_7[41][2]',
#                                                                   'lstm_6[43][0]',
#                                                                   'lstm_7[42][1]',
#                                                                   'lstm_7[42][2]',
#                                                                   'lstm_6[44][0]',
#                                                                   'lstm_7[43][1]',
#                                                                   'lstm_7[43][2]',
#                                                                   'lstm_6[45][0]',
#                                                                   'lstm_7[44][1]',
#                                                                   'lstm_7[44][2]',
#                                                                   'lstm_6[46][0]',
#                                                                   'lstm_7[45][1]',
#                                                                   'lstm_7[45][2]',
#                                                                   'lstm_6[47][0]',
#                                                                   'lstm_7[46][1]',
#                                                                   'lstm_7[46][2]']
#
#  future_dates (InputLayer)      [(None, 48, 18)]     0           []
#
#  lstm_8 (LSTM)                  [(None, 16),         2112        ['lstm_7[0][0]',
#                                  (None, 16),                      'lstm_7[1][0]',
#                                  (None, 16)]                      'lstm_8[0][1]',
#                                                                   'lstm_8[0][2]',
#                                                                   'lstm_7[2][0]',
#                                                                   'lstm_8[1][1]',
#                                                                   'lstm_8[1][2]',
#                                                                   'lstm_7[3][0]',
#                                                                   'lstm_8[2][1]',
#                                                                   'lstm_8[2][2]',
#                                                                   'lstm_7[4][0]',
#                                                                   'lstm_8[3][1]',
#                                                                   'lstm_8[3][2]',
#                                                                   'lstm_7[5][0]',
#                                                                   'lstm_8[4][1]',
#                                                                   'lstm_8[4][2]',
#                                                                   'lstm_7[6][0]',
#                                                                   'lstm_8[5][1]',
#                                                                   'lstm_8[5][2]',
#                                                                   'lstm_7[7][0]',
#                                                                   'lstm_8[6][1]',
#                                                                   'lstm_8[6][2]',
#                                                                   'lstm_7[8][0]',
#                                                                   'lstm_8[7][1]',
#                                                                   'lstm_8[7][2]',
#                                                                   'lstm_7[9][0]',
#                                                                   'lstm_8[8][1]',
#                                                                   'lstm_8[8][2]',
#                                                                   'lstm_7[10][0]',
#                                                                   'lstm_8[9][1]',
#                                                                   'lstm_8[9][2]',
#                                                                   'lstm_7[11][0]',
#                                                                   'lstm_8[10][1]',
#                                                                   'lstm_8[10][2]',
#                                                                   'lstm_7[12][0]',
#                                                                   'lstm_8[11][1]',
#                                                                   'lstm_8[11][2]',
#                                                                   'lstm_7[13][0]',
#                                                                   'lstm_8[12][1]',
#                                                                   'lstm_8[12][2]',
#                                                                   'lstm_7[14][0]',
#                                                                   'lstm_8[13][1]',
#                                                                   'lstm_8[13][2]',
#                                                                   'lstm_7[15][0]',
#                                                                   'lstm_8[14][1]',
#                                                                   'lstm_8[14][2]',
#                                                                   'lstm_7[16][0]',
#                                                                   'lstm_8[15][1]',
#                                                                   'lstm_8[15][2]',
#                                                                   'lstm_7[17][0]',
#                                                                   'lstm_8[16][1]',
#                                                                   'lstm_8[16][2]',
#                                                                   'lstm_7[18][0]',
#                                                                   'lstm_8[17][1]',
#                                                                   'lstm_8[17][2]',
#                                                                   'lstm_7[19][0]',
#                                                                   'lstm_8[18][1]',
#                                                                   'lstm_8[18][2]',
#                                                                   'lstm_7[20][0]',
#                                                                   'lstm_8[19][1]',
#                                                                   'lstm_8[19][2]',
#                                                                   'lstm_7[21][0]',
#                                                                   'lstm_8[20][1]',
#                                                                   'lstm_8[20][2]',
#                                                                   'lstm_7[22][0]',
#                                                                   'lstm_8[21][1]',
#                                                                   'lstm_8[21][2]',
#                                                                   'lstm_7[23][0]',
#                                                                   'lstm_8[22][1]',
#                                                                   'lstm_8[22][2]',
#                                                                   'lstm_7[24][0]',
#                                                                   'lstm_8[23][1]',
#                                                                   'lstm_8[23][2]',
#                                                                   'lstm_7[25][0]',
#                                                                   'lstm_8[24][1]',
#                                                                   'lstm_8[24][2]',
#                                                                   'lstm_7[26][0]',
#                                                                   'lstm_8[25][1]',
#                                                                   'lstm_8[25][2]',
#                                                                   'lstm_7[27][0]',
#                                                                   'lstm_8[26][1]',
#                                                                   'lstm_8[26][2]',
#                                                                   'lstm_7[28][0]',
#                                                                   'lstm_8[27][1]',
#                                                                   'lstm_8[27][2]',
#                                                                   'lstm_7[29][0]',
#                                                                   'lstm_8[28][1]',
#                                                                   'lstm_8[28][2]',
#                                                                   'lstm_7[30][0]',
#                                                                   'lstm_8[29][1]',
#                                                                   'lstm_8[29][2]',
#                                                                   'lstm_7[31][0]',
#                                                                   'lstm_8[30][1]',
#                                                                   'lstm_8[30][2]',
#                                                                   'lstm_7[32][0]',
#                                                                   'lstm_8[31][1]',
#                                                                   'lstm_8[31][2]',
#                                                                   'lstm_7[33][0]',
#                                                                   'lstm_8[32][1]',
#                                                                   'lstm_8[32][2]',
#                                                                   'lstm_7[34][0]',
#                                                                   'lstm_8[33][1]',
#                                                                   'lstm_8[33][2]',
#                                                                   'lstm_7[35][0]',
#                                                                   'lstm_8[34][1]',
#                                                                   'lstm_8[34][2]',
#                                                                   'lstm_7[36][0]',
#                                                                   'lstm_8[35][1]',
#                                                                   'lstm_8[35][2]',
#                                                                   'lstm_7[37][0]',
#                                                                   'lstm_8[36][1]',
#                                                                   'lstm_8[36][2]',
#                                                                   'lstm_7[38][0]',
#                                                                   'lstm_8[37][1]',
#                                                                   'lstm_8[37][2]',
#                                                                   'lstm_7[39][0]',
#                                                                   'lstm_8[38][1]',
#                                                                   'lstm_8[38][2]',
#                                                                   'lstm_7[40][0]',
#                                                                   'lstm_8[39][1]',
#                                                                   'lstm_8[39][2]',
#                                                                   'lstm_7[41][0]',
#                                                                   'lstm_8[40][1]',
#                                                                   'lstm_8[40][2]',
#                                                                   'lstm_7[42][0]',
#                                                                   'lstm_8[41][1]',
#                                                                   'lstm_8[41][2]',
#                                                                   'lstm_7[43][0]',
#                                                                   'lstm_8[42][1]',
#                                                                   'lstm_8[42][2]',
#                                                                   'lstm_7[44][0]',
#                                                                   'lstm_8[43][1]',
#                                                                   'lstm_8[43][2]',
#                                                                   'lstm_7[45][0]',
#                                                                   'lstm_8[44][1]',
#                                                                   'lstm_8[44][2]',
#                                                                   'lstm_7[46][0]',
#                                                                   'lstm_8[45][1]',
#                                                                   'lstm_8[45][2]',
#                                                                   'lstm_7[47][0]',
#                                                                   'lstm_8[46][1]',
#                                                                   'lstm_8[46][2]']
#
#  tf.__operators__.getitem_48 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_48 (TFOpLambda)      (None, 34)           0           ['lstm_8[0][0]',
#                                                                   'tf.__operators__.getitem_48[0][
#                                                                  0]']
#
#  dense_6 (Dense)                (None, 16)           560         ['tf.concat_48[0][0]',
#                                                                   'tf.concat_49[0][0]',
#                                                                   'tf.concat_50[0][0]',
#                                                                   'tf.concat_51[0][0]',
#                                                                   'tf.concat_52[0][0]',
#                                                                   'tf.concat_53[0][0]',
#                                                                   'tf.concat_54[0][0]',
#                                                                   'tf.concat_55[0][0]',
#                                                                   'tf.concat_56[0][0]',
#                                                                   'tf.concat_57[0][0]',
#                                                                   'tf.concat_58[0][0]',
#                                                                   'tf.concat_59[0][0]',
#                                                                   'tf.concat_60[0][0]',
#                                                                   'tf.concat_61[0][0]',
#                                                                   'tf.concat_62[0][0]',
#                                                                   'tf.concat_63[0][0]',
#                                                                   'tf.concat_64[0][0]',
#                                                                   'tf.concat_65[0][0]',
#                                                                   'tf.concat_66[0][0]',
#                                                                   'tf.concat_67[0][0]',
#                                                                   'tf.concat_68[0][0]',
#                                                                   'tf.concat_69[0][0]',
#                                                                   'tf.concat_70[0][0]',
#                                                                   'tf.concat_71[0][0]',
#                                                                   'tf.concat_72[0][0]',
#                                                                   'tf.concat_73[0][0]',
#                                                                   'tf.concat_74[0][0]',
#                                                                   'tf.concat_75[0][0]',
#                                                                   'tf.concat_76[0][0]',
#                                                                   'tf.concat_77[0][0]',
#                                                                   'tf.concat_78[0][0]',
#                                                                   'tf.concat_79[0][0]',
#                                                                   'tf.concat_80[0][0]',
#                                                                   'tf.concat_81[0][0]',
#                                                                   'tf.concat_82[0][0]',
#                                                                   'tf.concat_83[0][0]',
#                                                                   'tf.concat_84[0][0]',
#                                                                   'tf.concat_85[0][0]',
#                                                                   'tf.concat_86[0][0]',
#                                                                   'tf.concat_87[0][0]',
#                                                                   'tf.concat_88[0][0]',
#                                                                   'tf.concat_89[0][0]',
# ...
#                                                                  0]']
#
#  tf.expand_dims_82 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[35][0]']
#
#  tf.__operators__.getitem_84 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_84 (TFOpLambda)      (None, 34)           0           ['lstm_8[36][0]',
#                                                                   'tf.__operators__.getitem_84[0][
#                                                                  0]']
#
#  tf.expand_dims_83 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[36][0]']
#
#  tf.__operators__.getitem_85 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_85 (TFOpLambda)      (None, 34)           0           ['lstm_8[37][0]',
#                                                                   'tf.__operators__.getitem_85[0][
#                                                                  0]']
#
#  tf.expand_dims_84 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[37][0]']
#
#  tf.__operators__.getitem_86 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_86 (TFOpLambda)      (None, 34)           0           ['lstm_8[38][0]',
#                                                                   'tf.__operators__.getitem_86[0][
#                                                                  0]']
#
#  tf.expand_dims_85 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[38][0]']
#
#  tf.__operators__.getitem_87 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_87 (TFOpLambda)      (None, 34)           0           ['lstm_8[39][0]',
#                                                                   'tf.__operators__.getitem_87[0][
#                                                                  0]']
#
#  tf.expand_dims_86 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[39][0]']
#
#  tf.__operators__.getitem_88 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_88 (TFOpLambda)      (None, 34)           0           ['lstm_8[40][0]',
#                                                                   'tf.__operators__.getitem_88[0][
#                                                                  0]']
#
#  tf.expand_dims_87 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[40][0]']
#
#  tf.__operators__.getitem_89 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_89 (TFOpLambda)      (None, 34)           0           ['lstm_8[41][0]',
#                                                                   'tf.__operators__.getitem_89[0][
#                                                                  0]']
#
#  tf.expand_dims_88 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[41][0]']
#
#  tf.__operators__.getitem_90 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_90 (TFOpLambda)      (None, 34)           0           ['lstm_8[42][0]',
#                                                                   'tf.__operators__.getitem_90[0][
#                                                                  0]']
#
#  tf.expand_dims_89 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[42][0]']
#
#  tf.__operators__.getitem_91 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_91 (TFOpLambda)      (None, 34)           0           ['lstm_8[43][0]',
#                                                                   'tf.__operators__.getitem_91[0][
#                                                                  0]']
#
#  tf.expand_dims_90 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[43][0]']
#
#  tf.__operators__.getitem_92 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_92 (TFOpLambda)      (None, 34)           0           ['lstm_8[44][0]',
#                                                                   'tf.__operators__.getitem_92[0][
#                                                                  0]']
#
#  tf.expand_dims_91 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[44][0]']
#
#  tf.__operators__.getitem_93 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_93 (TFOpLambda)      (None, 34)           0           ['lstm_8[45][0]',
#                                                                   'tf.__operators__.getitem_93[0][
#                                                                  0]']
#
#  tf.expand_dims_92 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[45][0]']
#
#  tf.__operators__.getitem_94 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_94 (TFOpLambda)      (None, 34)           0           ['lstm_8[46][0]',
#                                                                   'tf.__operators__.getitem_94[0][
#                                                                  0]']
#
#  tf.expand_dims_93 (TFOpLambda)  (None, 1, 1)        0           ['dense_8[46][0]']
#
#  tf.__operators__.getitem_95 (S  (None, 18)          0           ['future_dates[0][0]']
#  licingOpLambda)
#
#  tf.concat_95 (TFOpLambda)      (None, 34)           0           ['lstm_8[47][0]',
#                                                                   'tf.__operators__.getitem_95[0][
#                                                                  0]']
#
#  lambda_1 (Lambda)              (None, 48)           0           ['dense_8[0][0]',
#                                                                   'dense_8[1][0]',
#                                                                   'dense_8[2][0]',
#                                                                   'dense_8[3][0]',
#                                                                   'dense_8[4][0]',
#                                                                   'dense_8[5][0]',
#                                                                   'dense_8[6][0]',
#                                                                   'dense_8[7][0]',
#                                                                   'dense_8[8][0]',
#                                                                   'dense_8[9][0]',
#                                                                   'dense_8[10][0]',
#                                                                   'dense_8[11][0]',
#                                                                   'dense_8[12][0]',
#                                                                   'dense_8[13][0]',
#                                                                   'dense_8[14][0]',
#                                                                   'dense_8[15][0]',
#                                                                   'dense_8[16][0]',
#                                                                   'dense_8[17][0]',
#                                                                   'dense_8[18][0]',
#                                                                   'dense_8[19][0]',
#                                                                   'dense_8[20][0]',
#                                                                   'dense_8[21][0]',
#                                                                   'dense_8[22][0]',
#                                                                   'dense_8[23][0]',
#                                                                   'dense_8[24][0]',
#                                                                   'dense_8[25][0]',
#                                                                   'dense_8[26][0]',
#                                                                   'dense_8[27][0]',
#                                                                   'dense_8[28][0]',
#                                                                   'dense_8[29][0]',
#                                                                   'dense_8[30][0]',
#                                                                   'dense_8[31][0]',
#                                                                   'dense_8[32][0]',
#                                                                   'dense_8[33][0]',
#                                                                   'dense_8[34][0]',
#                                                                   'dense_8[35][0]',
#                                                                   'dense_8[36][0]',
#                                                                   'dense_8[37][0]',
#                                                                   'dense_8[38][0]',
#                                                                   'dense_8[39][0]',
#                                                                   'dense_8[40][0]',
#                                                                   'dense_8[41][0]',
#                                                                   'dense_8[42][0]',
#                                                                   'dense_8[43][0]',
#                                                                   'dense_8[44][0]',
#                                                                   'dense_8[45][0]',
#                                                                   'dense_8[46][0]',
#                                                                   'dense_8[47][0]']
#
# ==================================================================================================
# Total params: 6,081
# Trainable params: 6,081
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# 514951

# %% [markdown]
# ## **Train Loop**

# %%
def train_model(model, train_ds, val_ds):
    reducer = tf.keras.callbacks.ReduceLROnPlateau(monior='val_loss', factor=0.1, patience=2, mode='min', cooldown=1)
    stopper = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, mode='min', restore_best_weights=True)
    model.fit(train_ds,
              epochs=config["EPOCHS"], 
              callbacks=[reducer, stopper, WandbCallback()],
              validation_data=val_ds)
    return model

def test_model(model, X_test, y_test, future_test, normalizer):
    predictions = model.predict({'series':X_test, 'future_dates':future_test})
    inversed_predictions, inversed_actuals = [], []
    for pred, actual in zip(predictions, y_test):
        inversed_predictions.append(normalizer.inverse_transform(np.array(pred).reshape(-1,1)).reshape((-1)))
        inversed_actuals.append(normalizer.inverse_transform(np.array(actual).reshape(-1,1)).reshape((-1)))
    inversed_predictions = np.array(inversed_predictions)
    inversed_actuals = np.array(inversed_actuals)
    forward_error = np.mean(np.abs(inversed_actuals - inversed_predictions), axis=-1)
    error = np.mean(forward_error)
    return error, forward_error, inversed_predictions, inversed_actuals

def record_forward_error(forward_errors, error, run):
    run.log({'test/error': error})
    run.log({'test/forward_error': wandb.plot.line_series(
        xs=[i+1 for i in range(forward_errors.shape[0])],
        ys=[forward_errors],
        keys=['Forward Horizon Errors'],
        title=f'Forward Horizon Errors (MAE: {error})',
    )})
        
def graph_predictions(predictions, actuals, dates, run):
    for look_ahead in [1, 12, 24, 36, 48]:
        preds, true, time = predictions[:, look_ahead-1], actuals[:, look_ahead-1], dates[:, look_ahead-1]
        error = np.mean(np.abs(true - preds))
        run.log({f'test/forecast-{look_ahead}-hours-ahead': wandb.plot.line_series(
            xs=time,
            ys=[true, preds],
            keys=['Actuals', 'Predictions'],
            title=f'{look_ahead} Hour(s) Ahead Forecast (MAE: {error})',
            xname='week'
        )})

# %%
def train():
    for fold in range(1, 4):
        run = wandb.init(project="time-series-methods", entity="kmcguigan", group=f"{MODEL}-model", config=config, job_type="train")
        run.name = f'{MODEL}-fold-{fold}'
        (train_ds, val_ds, X_test, y_test, future_test, dates), normalizer = get_data(fold)
        model = get_model()
        model = train_model(model, train_ds, val_ds)
        error, forward_errors, predictions, actuals = test_model(model, X_test, y_test, future_test, normalizer)
        run.log({'test-error': error})
        record_forward_error(forward_errors, error, run)
        graph_predictions(predictions, actuals, dates, run)
        run.finish()
        del model
        del train_ds
        del val_ds
        gc.collect()
    return

# %%
train()
# Out:
# Finishing last run (ID:3nc5q91t) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">kind-elevator-52</strong>: <a href="https://wandb.ai/kmcguigan/time-series-methods/runs/3nc5q91t" target="_blank">https://wandb.ai/kmcguigan/time-series-methods/runs/3nc5q91t</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220605_193251-3nc5q91t\logs</code>
# Successfully finished last run (ID:3nc5q91t). Initializing new run:<br/>
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>C:\Users\KiernanMcGuigan\MyFolders\code\GitRepositories\Time-Series-Playground\wandb\run-20220605_193544-1a4iosfa</code>
# Syncing run <strong><a href="https://wandb.ai/kmcguigan/time-series-methods/runs/1a4iosfa" target="_blank">exalted-spaceship-54</a></strong> to <a href="https://wandb.ai/kmcguigan/time-series-methods" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Data Shape: (159096, 23), Reduced Shape (1000,)
# Data Shape: (43390, 23), Reduced Shape (1000,)
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# Epoch 1/2
# 3/3 [==============================] - 288s 32s/step - loss: 1.3729 - mae: 0.9682 - val_loss: 1.2285 - val_mae: 0.9059 - lr: 0.0010 - _timestamp: 1654479680.0000 - _runtime: 332.0000
# Epoch 2/2
# 3/3 [==============================] - 2s 752ms/step - loss: 1.2563 - mae: 0.9225 - val_loss: 1.1296 - val_mae: 0.8668 - lr: 0.0010 - _timestamp: 1654479682.0000 - _runtime: 334.0000
# 26/26 [==============================] - 56s 103ms/step
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.736 MB of 0.736 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁█</td></tr><tr><td>loss</td><td>█▁</td></tr><tr><td>lr</td><td>▁▁</td></tr><tr><td>mae</td><td>█▁</td></tr><tr><td>test-error</td><td>▁</td></tr><tr><td>test/error</td><td>▁</td></tr><tr><td>val_loss</td><td>█▁</td></tr><tr><td>val_mae</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>1.1296</td></tr><tr><td>epoch</td><td>1</td></tr><tr><td>loss</td><td>1.2563</td></tr><tr><td>lr</td><td>0.001</td></tr><tr><td>mae</td><td>0.92252</td></tr><tr><td>test-error</td><td>26.87885</td></tr><tr><td>test/error</td><td>26.87885</td></tr><tr><td>val_loss</td><td>1.1296</td></tr><tr><td>val_mae</td><td>0.86678</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">exalted-spaceship-54</strong>: <a href="https://wandb.ai/kmcguigan/time-series-methods/runs/1a4iosfa" target="_blank">https://wandb.ai/kmcguigan/time-series-methods/runs/1a4iosfa</a><br/>Synced 5 W&B file(s), 7 media file(s), 6 artifact file(s) and 1 other file(s)
# Find logs at: <code>.\wandb\run-20220605_193544-1a4iosfa\logs</code>
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>C:\Users\KiernanMcGuigan\MyFolders\code\GitRepositories\Time-Series-Playground\wandb\run-20220605_194302-tpbc1340</code>
# Syncing run <strong><a href="https://wandb.ai/kmcguigan/time-series-methods/runs/tpbc1340" target="_blank">peachy-mountain-56</a></strong> to <a href="https://wandb.ai/kmcguigan/time-series-methods" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Data Shape: (202486, 23), Reduced Shape (1000,)
# Data Shape: (43390, 23), Reduced Shape (1000,)
# Epoch 1/2
# 3/3 [==============================] - 290s 29s/step - loss: 2.4602 - mae: 1.3094 - val_loss: 2.3039 - val_mae: 1.2609 - lr: 0.0010 - _timestamp: 1654480115.0000 - _runtime: 333.0000
# Epoch 2/2
# 3/3 [==============================] - 2s 770ms/step - loss: 2.2890 - mae: 1.2641 - val_loss: 2.1550 - val_mae: 1.2206 - lr: 0.0010 - _timestamp: 1654480117.0000 - _runtime: 335.0000
# 26/26 [==============================] - 55s 92ms/step
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: ERROR Control-C detected -- Run data was not synced
# Exception ignored in: <function ScopedTFFunction.__del__ at 0x000001E52CCA1F78>
# Traceback (most recent call last):
#   File "C:\Users\KiernanMcGuigan\.conda\envs\ml-ts-env\lib\site-packages\tensorflow\python\framework\c_api_util.py", line 122, in __del__
#     self.deleter(func)
# KeyboardInterrupt
# Exception ignored in: <function _EagerDefinedFunctionDeleter.__del__ at 0x000001E52EDE4708>
# Traceback (most recent call last):
#   File "C:\Users\KiernanMcGuigan\.conda\envs\ml-ts-env\lib\site-packages\tensorflow\python\eager\function.py", line 304, in __del__
#     context.remove_function(self.name)
#   File "C:\Users\KiernanMcGuigan\.conda\envs\ml-ts-env\lib\site-packages\tensorflow\python\eager\context.py", line 2719, in remove_function
#     context().remove_function(name)
# KeyboardInterrupt:
