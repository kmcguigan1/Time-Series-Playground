# %%
import os
import pickle
import gc

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':16})
import seaborn as sns

from scipy import stats
from scipy.stats import normaltest, probplot, kstest
from statsmodels.tsa.stattools import kpss, adfuller

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.regularizers import L1L2

from tensorflow_probability import distributions as tfd

# %%
MODEL = "encoder-decoder-mdn"

config = {    
    "EMBEDDING_SIZE": 16,
    "DENSE_SIZE": 16, 
    "DROPOUT": 0.2,
    
    "N_PROB": 2,
    
    "LR": 0.001,
    "BATCH_SIZE": 16,
    "EPOCHS": 30,
}

# %%
RUN_WANDB = False

if(RUN_WANDB):
    import wandb
    from wandb.keras import WandbCallback
    from secrets import WANDB
    wandb.login(key=WANDB)

# %% [markdown]
# ## **Load Data Function**

# %%
def get_data(fold):
    df = pd.read_csv(f'./data/fold_{fold}.csv')
    with open(f'./data/fold_{fold}.npy', mode='rb') as f:
        train_historical_series = np.load(f, allow_pickle=False)
        train_historical_covariates = np.load(f, allow_pickle=False) 
        train_future_covariates = np.load(f, allow_pickle=False)
        train_future_series = np.load(f, allow_pickle=False)
        # val arrays
        val_historical_series = np.load(f, allow_pickle=False)
        val_historical_covariates = np.load(f, allow_pickle=False) 
        val_future_covariates = np.load(f, allow_pickle=False)
        val_future_series = np.load(f, allow_pickle=False)
        # test arrays
        test_historical_series = np.load(f, allow_pickle=False)
        test_historical_covariates = np.load(f, allow_pickle=False) 
        test_future_covariates = np.load(f, allow_pickle=False)
        test_future_series = np.load(f, allow_pickle=False)
        # forecast arrays
        forecast_historical_series = np.load(f, allow_pickle=False)
        forecast_historical_covariates = np.load(f, allow_pickle=False) 
        forecast_future_covariates = np.load(f, allow_pickle=False)
        forecast_future_series = np.load(f, allow_pickle=False)
        forecast_dates = np.load(f, allow_pickle=True)
        forecast_historical_dates = np.load(f, allow_pickle=True)
        # data info
        data_features = np.load(f, allow_pickle=False)
    return (
        (train_historical_series,train_historical_covariates,train_future_covariates),
        train_future_series, 
        (val_historical_series,val_historical_covariates,val_future_covariates),
        val_future_series, 
        (test_historical_series,test_historical_covariates,test_future_covariates), 
        test_future_series,
        (forecast_historical_series,forecast_historical_covariates,forecast_future_covariates), 
        forecast_future_series,
        forecast_dates,
        forecast_historical_dates,
        data_features,
        df
    )

X_train, y_train, X_val, y_val, X_test, y_test, X_forecast, y_forecast, forecast_dates, forecast_historical_dates, data_features, df = get_data(2)
print(data_features)
df
# Out:
# [30.73084645 29.04061676]
#                   datetime  level
# 0      2005-12-31 12:00:00   60.0
# 1      2005-12-31 13:00:00   43.0
# 2      2005-12-31 14:00:00   23.0
# 3      2005-12-31 15:00:00    1.0
# 4      2005-12-31 16:00:00  -12.0
# ...                    ...    ...
# 52591  2011-12-31 19:00:00    0.0
# 52592  2011-12-31 20:00:00   -2.0
# 52593  2011-12-31 21:00:00    2.0
# 52594  2011-12-31 22:00:00    9.0
# 52595  2011-12-31 23:00:00   15.0
#
# [52596 rows x 2 columns]

# %%
X_train[0].shape, X_train[1].shape, X_train[2].shape, y_train.shape
# Out:
# ((43734, 72, 1), (43734, 72, 4), (43734, 1, 4), (43734, 1))

# %% [markdown]
# ## **Model Functions**

# %% [markdown]
# https://www.youtube.com/watch?v=p6mKFs6HVlg

# %%
def nnelu(input):
    """ Computes the Non-Negative Exponential Linear Unit
    """
    return tf.add(tf.constant(1, dtype=tf.float32), tf.nn.elu(input))

tf.keras.utils.get_custom_objects().update({'nnelu': tf.keras.layers.Activation(nnelu)})

def identity(y_true, y_pred):
    return K.mean(y_pred)

def variational_loss(y_true, mu, sigma):
    inv_sigma_2 = 1 / K.square(sigma + K.epsilon())
    phi = inv_sigma_2 * K.exp(-inv_sigma_2 * K.square(y_true - mu))
    return -K.log(phi + K.epsilon())

def mdn_loss(y_true, mu, sigma, alpha):
    print("mu: ", mu.shape)
    print("sigma: ", sigma.shape)
    print("alpha: ", alpha.shape)
    inv_sigma_2 = 1 / K.square(sigma + K.epsilon())
    print("inv_sigma_2: ", inv_sigma_2.shape)
    phi = inv_sigma_2 * K.exp(-inv_sigma_2 * K.square(y_true - mu))
    print("phi: ", phi.shape)
    loss = -K.log(phi + K.epsilon())
    loss *= alpha
    print("loss: ", loss.shape)
    return loss

def gnll_loss(y, mu, sigma, alpha):
    """ Computes the mean negative log-likelihood loss of y given the mixture parameters.
    """    
    gm = tfd.MixtureSameFamily(
        mixture_distribution=tfd.Categorical(probs=alpha),
        components_distribution=tfd.Normal(
            loc=mu,       
            scale=sigma
        )
    )
    log_likelihood = gm.log_prob(tf.transpose(y))   
    return -tf.reduce_mean(log_likelihood, axis=-1)

def gnll_metric(y, mu, sigma, alpha):
    """ Computes the mean negative log-likelihood loss of y given the mixture parameters.
    """    
    gm = tfd.MixtureSameFamily(
        mixture_distribution=tfd.Categorical(probs=alpha),
        components_distribution=tfd.Normal(
            loc=mu,       
            scale=sigma
        )
    )
    
    probability = gm.prob(tf.transpose(y))         
    return tf.reduce_mean(probability, axis=-1)

def simple_encoder_decoder(historical_series_shape, historical_covariates_shape, future_covariates_shape, future_series_shape):
    historical_series = tf.keras.layers.Input(shape=historical_series_shape)
    historical_covariates = tf.keras.layers.Input(shape=historical_covariates_shape)
    future_covariates = tf.keras.layers.Input(shape=future_covariates_shape)
    future_series = tf.keras.layers.Input(shape=future_series_shape)
    
    historicals = tf.keras.layers.Concatenate()([historical_series, historical_covariates])
    encoder = tf.keras.layers.LSTM(config["EMBEDDING_SIZE"], 
                                   return_sequences=True, 
                                   return_state=False, 
                                   recurrent_initializer='glorot_uniform')(historicals)
    encoder = tf.keras.layers.LSTM(config["EMBEDDING_SIZE"], 
                                   return_sequences=False, 
                                   return_state=False, 
                                   recurrent_initializer='glorot_uniform')(encoder)
    
    encoder = tf.expand_dims(encoder, 1)
    encoded_inputs = tf.keras.layers.Concatenate()([future_covariates, encoder])
    encoded_inputs = tf.squeeze(encoded_inputs, axis=1)
    encoded_inputs = tf.keras.layers.Dropout(config["DROPOUT"])(encoded_inputs)
    
    decoder = tf.keras.layers.Dense(config["DENSE_SIZE"])(encoded_inputs)
    decoder = tf.keras.layers.BatchNormalization()(decoder)
    decoder = tf.keras.layers.Activation('relu')(decoder)
    
    mu = tf.keras.layers.Dense(config['N_PROB'], name="mu")(decoder)
    sigma = tf.keras.layers.Dense(config['N_PROB'], name="sigma", activation="softplus")(decoder)
    alpha = tf.keras.layers.Dense(config['N_PROB'], name="alpha", activation="softmax")(decoder)
    loss = tf.keras.layers.Lambda(lambda x: gnll_loss(x[0], x[1], x[2], x[3]), name="loss")([future_series,mu,sigma,alpha])
    probability = tf.keras.layers.Lambda(lambda x: gnll_metric(x[0], x[1], x[2], x[3]), name="probability")([future_series,mu,sigma,alpha])
    print(probability)
    # calculate the loss and record info
    print(loss)
    forecast_outputs = tf.stack([mu, sigma, alpha], axis=1)
    
    model = tf.keras.models.Model(inputs=[historical_series,historical_covariates,future_covariates,future_series], outputs=loss)
    forecaster = tf.keras.models.Model(inputs=[historical_series,historical_covariates,future_covariates], outputs=forecast_outputs)
    model.add_metric(probability, name="Probability")
    model.compile(loss=identity, optimizer=tf.keras.optimizers.Adam(learning_rate=config["LR"]))
    return model, forecaster

model, forecaster = simple_encoder_decoder(X_train[0].shape[1:], X_train[1].shape[1:], X_train[2].shape[1:], y_train.shape[1:])
model.summary()
# Out:
# Metal device set to: Apple M1 Pro
# 2022-12-20 13:59:56.641082: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-20 13:59:56.641220: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# KerasTensor(type_spec=TensorSpec(shape=(1,), dtype=tf.float32, name=None), name='probability/Mean:0', description="created by layer 'probability'")
# KerasTensor(type_spec=TensorSpec(shape=(1,), dtype=tf.float32, name=None), name='loss/Neg:0', description="created by layer 'loss'")
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 72, 1)]      0           []
#
#  input_2 (InputLayer)           [(None, 72, 4)]      0           []
#
#  concatenate (Concatenate)      (None, 72, 5)        0           ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  lstm (LSTM)                    (None, 72, 16)       1408        ['concatenate[0][0]']
#
#  lstm_1 (LSTM)                  (None, 16)           2112        ['lstm[0][0]']
#
#  input_3 (InputLayer)           [(None, 1, 4)]       0           []
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 16)        0           ['lstm_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 1, 20)        0           ['input_3[0][0]',
#                                                                   'tf.expand_dims[0][0]']
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 20)          0           ['concatenate_1[0][0]']
#  da)
#
#  dropout (Dropout)              (None, 20)           0           ['tf.compat.v1.squeeze[0][0]']
#
#  dense (Dense)                  (None, 16)           336         ['dropout[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16)          64          ['dense[0][0]']
#  alization)
#
#  activation_1 (Activation)      (None, 16)           0           ['batch_normalization[0][0]']
#
#  input_4 (InputLayer)           [(None, 1)]          0           []
#
#  mu (Dense)                     (None, 2)            34          ['activation_1[0][0]']
#
#  sigma (Dense)                  (None, 2)            34          ['activation_1[0][0]']
#
#  alpha (Dense)                  (None, 2)            34          ['activation_1[0][0]']
#
#  loss (Lambda)                  (1,)                 0           ['input_4[0][0]',
#                                                                   'mu[0][0]',
#                                                                   'sigma[0][0]',
#                                                                   'alpha[0][0]']
#
#  probability (Lambda)           (1,)                 0           ['input_4[0][0]',
#                                                                   'mu[0][0]',
#                                                                   'sigma[0][0]',
#                                                                   'alpha[0][0]']
#
#  add_metric (AddMetric)         (1,)                 0           ['probability[0][0]']
#
# ==================================================================================================
# Total params: 4,022
# Trainable params: 3,990
# Non-trainable params: 32
# __________________________________________________________________________________________________

# %%
reducer = tf.keras.callbacks.ReduceLROnPlateau(monior='val_loss', factor=0.1, patience=2, mode='min', cooldown=1)
stopper = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, mode='min', restore_best_weights=True)
if(RUN_WANDB):
    callbacks = [reducer, stopper, WandbCallback()]
else:
    callbacks = [reducer, stopper]
    
model.fit((*X_train,y_train), y_train,
          batch_size=config["BATCH_SIZE"],
          epochs=config["EPOCHS"], 
          callbacks=callbacks,
          validation_data=((*X_val,y_val), y_val),
          validation_batch_size=config["BATCH_SIZE"],
          shuffle=True)
# Out:
# Epoch 1/30
# 2022-12-20 13:59:57.165408: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-12-20 13:59:58.686761: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 13:59:58.915629: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 13:59:59.061931: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 13:59:59.590917: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 13:59:59.866609: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - ETA: 0s - loss: 0.7043 - Probability: 0.6231
# 2022-12-20 14:02:09.825378: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 14:02:09.910537: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 14:02:10.030453: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2734/2734 [==============================] - 147s 53ms/step - loss: 0.7043 - Probability: 0.6231 - val_loss: -0.1458 - val_Probability: 1.1742 - lr: 0.0010
# Epoch 2/30
# 2734/2734 [==============================] - 144s 53ms/step - loss: 0.2005 - Probability: 0.9660 - val_loss: -0.2258 - val_Probability: 1.2874 - lr: 0.0010
# Epoch 3/30
# 2734/2734 [==============================] - 144s 53ms/step - loss: -0.0264 - Probability: 1.2315 - val_loss: -0.4521 - val_Probability: 1.6621 - lr: 0.0010
# Epoch 4/30
# 2734/2734 [==============================] - 146s 53ms/step - loss: -0.2045 - Probability: 1.5031 - val_loss: -0.4528 - val_Probability: 1.7403 - lr: 0.0010
# Epoch 5/30
# 2734/2734 [==============================] - 145s 53ms/step - loss: -0.3250 - Probability: 1.7132 - val_loss: -0.6506 - val_Probability: 2.1240 - lr: 0.0010
# Epoch 6/30
# 2734/2734 [==============================] - 146s 53ms/step - loss: -0.4141 - Probability: 1.8815 - val_loss: -0.5801 - val_Probability: 2.0418 - lr: 0.0010
# Epoch 7/30
# 2734/2734 [==============================] - 160s 58ms/step - loss: -0.4721 - Probability: 1.9945 - val_loss: -0.6328 - val_Probability: 2.1707 - lr: 0.0010
# Epoch 8/30
# 2734/2734 [==============================] - 161s 59ms/step - loss: -0.5466 - Probability: 2.1427 - val_loss: -0.7422 - val_Probability: 2.3660 - lr: 1.0000e-04
# Epoch 9/30
# 2734/2734 [==============================] - 163s 59ms/step - loss: -0.5620 - Probability: 2.1836 - val_loss: -0.7493 - val_Probability: 2.3915 - lr: 1.0000e-04
# Epoch 10/30
# 2734/2734 [==============================] - 159s 58ms/step - loss: -0.5615 - Probability: 2.1883 - val_loss: -0.7294 - val_Probability: 2.3562 - lr: 1.0000e-04
# Epoch 11/30
# 2734/2734 [==============================] - 155s 57ms/step - loss: -0.5687 - Probability: 2.2116 - val_loss: -0.7526 - val_Probability: 2.3871 - lr: 1.0000e-04
# Epoch 12/30
# 2734/2734 [==============================] - 150s 55ms/step - loss: -0.5769 - Probability: 2.2219 - val_loss: -0.7404 - val_Probability: 2.3987 - lr: 1.0000e-04
# Epoch 13/30
# 2734/2734 [==============================] - 153s 56ms/step - loss: -0.5842 - Probability: 2.2489 - val_loss: -0.7530 - val_Probability: 2.4143 - lr: 1.0000e-04
# Epoch 14/30
# 2734/2734 [==============================] - 153s 56ms/step - loss: -0.5818 - Probability: 2.2367 - val_loss: -0.7665 - val_Probability: 2.4318 - lr: 1.0000e-04
# Epoch 15/30
# 2734/2734 [==============================] - 153s 56ms/step - loss: -0.5914 - Probability: 2.2603 - val_loss: -0.7310 - val_Probability: 2.3918 - lr: 1.0000e-04
# Epoch 16/30
# 2734/2734 [==============================] - 149s 55ms/step - loss: -0.5992 - Probability: 2.2722 - val_loss: -0.7290 - val_Probability: 2.4093 - lr: 1.0000e-04
# Epoch 17/30
# 2734/2734 [==============================] - 153s 56ms/step - loss: -0.5970 - Probability: 2.2873 - val_loss: -0.7422 - val_Probability: 2.4253 - lr: 1.0000e-05
# Epoch 18/30
# 2734/2734 [==============================] - 154s 56ms/step - loss: -0.6042 - Probability: 2.2856 - val_loss: -0.7418 - val_Probability: 2.4213 - lr: 1.0000e-05

# %%
model.evaluate((*X_test,y_test), y_test)
# Out:
# 271/271 [==============================] - 8s 29ms/step - loss: -0.7058 - Probability: 2.3578
# [-0.7058345079421997, 2.3578379154205322]

# %% [markdown]
# ## **Single Step Prediction Analysis**

# %%
def sample_distribution(single_step_predictions):
    gm = tfd.MixtureSameFamily(
        mixture_distribution=tfd.Categorical(probs=single_step_predictions[:,2,:]),
        components_distribution=tfd.Normal(
            loc=single_step_predictions[:,0,:],       
            scale=single_step_predictions[:,1,:]
        )
    )
    return tf.transpose(gm.sample(sample_shape=(1000))).numpy()

single_step_predictions_all = forecaster.predict(X_test)
single_step_predictions_all = sample_distribution(single_step_predictions_all)
single_step_predictions = single_step_predictions_all.mean(axis=-1)
single_step_predictions = np.expand_dims(single_step_predictions, axis=-1)
single_step_predictions.shape
# Out:
# 2022-12-20 14:45:41.831494: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 14:45:41.905559: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-12-20 14:45:42.031017: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 271/271 [==============================] - 8s 24ms/step
# (8670, 1)

# %%
real_single_step_predictions_all = (single_step_predictions_all * data_features[1]) + data_features[0]
real_single_step_predictions = (single_step_predictions * data_features[1]) + data_features[0]
single_step_actuals = (y_test * data_features[1]) + data_features[0]
real_single_step_predictions.shape, single_step_actuals.shape, real_single_step_predictions_all.shape
# Out:
# ((8670, 1), (8670, 1), (8670, 1000))

# %%
sample_points = np.linspace(start=0, stop=real_single_step_predictions.shape[0]-1, num=8).astype(int)
for sample_point in sample_points:
    _, ax = plt.subplots(1,1,figsize=(22,8))
    ax.set_title(f"Forecast on {forecast_dates[sample_point,0]}", fontdict={'size':20})
    ax.set_ylabel("Density", fontdict={'size':16})
    ax.set_xlabel("Water Level", fontdict={'size':16})
    ax.hist(real_single_step_predictions_all[sample_point,:],bins=80,density=True,label="Probability Density")
    y_min, y_max = ax.get_ylim()
    ax.plot([single_step_actuals[sample_point,0],
             single_step_actuals[sample_point,0]],
            [y_min,y_max],
            'red', linewidth=2, alpha=0.75, label='Actual')
    ax.legend(loc='best')
    plt.show()

# %% [markdown]
# ### **Single Step Prediction Error Metrics**

# %%
def r_squared(predictions, actuals):
    sum_squared_regression = np.sum(np.square(actuals - predictions))
    total_sum_of_squares = np.sum(np.square(actuals - np.mean(actuals)))
    return 1 - (sum_squared_regression / total_sum_of_squares)

single_step_error = real_single_step_predictions - single_step_actuals
single_step_error = single_step_error.flatten()
single_step_rmse = np.sqrt(np.mean(np.square(real_single_step_predictions - single_step_actuals)))
single_step_mse = np.mean(np.square(real_single_step_predictions - single_step_actuals))
single_step_mae = np.mean(np.abs(real_single_step_predictions - single_step_actuals))
single_step_r2 = r_squared(real_single_step_predictions, single_step_actuals)
print(f"Single Step RMSE: {single_step_rmse:.4f}")
print(f"Single Step MSE:  {single_step_mse:.4f}")
print(f"Single Step MAE:  {single_step_mae:.4f}")
print(f"Single Step r2:   {single_step_r2*100:.4f}%")
# Out:
# Single Step RMSE: 3.9660
# Single Step MSE:  15.7293
# Single Step MAE:  2.8727
# Single Step r2:   98.1375%

# %% [markdown]
# ### **Single Step Prediction Forecasted VS Actuals**

# %%
_, ax = plt.subplots(1,1,figsize=(22,12))
ax.set_title("Single Step Forecasted VS Actuals", size=20)
ax.set_xlabel("Actual Level", size=16)
ax.set_ylabel("Forecasted Level", size=16)
ax.scatter(single_step_actuals, real_single_step_predictions)

min_ = np.min([np.min(single_step_actuals), np.min(real_single_step_predictions)]) - 4
max_ = np.max([np.max(single_step_actuals), np.max(real_single_step_predictions)]) + 2
ax.set_xlim([min_,max_])
ax.set_ylim([min_,max_])
ax.plot([min_,max_], [min_,max_], 'red', linewidth=2, alpha=0.5);
plt.show()

# %% [markdown]
# ### **Analyze the Residuals Over Time**

# %%
_, ax = plt.subplots(1,1,figsize=(22,12))
ax.set_title("Single Step Absolute Error of Forecast Over Time", size=20)
# ax.set_xlabel("Time Steps From Start of Test Portion", size=16)
# ax.set_ylabel("Absolute Error", size=16)
ax.plot(np.arange(len(single_step_error)), single_step_error);

# %%
# null is the presence of a unit root

dftest = adfuller(single_step_error, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
dfoutput
# Out:
# Test Statistic                -8.271307e+00
# p-value                        4.785031e-13
# #Lags Used                     3.600000e+01
# Number of Observations Used    8.633000e+03
# Critical Value (1%)           -3.431108e+00
# Critical Value (5%)           -2.861875e+00
# Critical Value (10%)          -2.566948e+00
# dtype: float64

# %%
# null is stationary

kpsstest = kpss(single_step_error, regression='c', nlags="auto")
kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','#Lags Used'])
for key,value in kpsstest[3].items():
    kpss_output['Critical Value (%s)'%key] = value
kpss_output
# Out:
# /Users/kiernan/miniforge3/envs/ml-ts-env/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# Test Statistic            4.635084
# p-value                   0.010000
# #Lags Used               37.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64

# %% [markdown]
# ### **Test the Normality of Residuals**

# %%
_, ax = plt.subplots(1,1,figsize=(22,12))
ax.set_title("Distribution of Single Step Absolute Error", size=20)
# ax.set_xlabel("Absolute Error", size=16)
# ax.set_ylabel("Density", size=16)
ax.hist(single_step_error, bins=40, density=True);

# %%
mean, sigma = single_step_error.mean(), single_step_error.std()
mean, sigma
# Out:
# (-2.1503118887904606, 3.3324848699564957)

# %% [markdown]
# ### **Test Normal Distribution**

# %%
kstest(single_step_error, stats.norm.cdf, args=(mean,sigma), N=len(single_step_error))
# Out:
# KstestResult(statistic=0.06659345233766634, pvalue=7.1356896469880165e-34)

# %%
_, ax = plt.subplots(1,1,figsize=(22,8))
probplot(single_step_error, dist=stats.norm, sparams=(mean,sigma), plot=ax);

# %%
data_norm = np.random.normal(mean, sigma, len(single_step_error))
_, ax = plt.subplots(1,1,figsize=(22,8))
sns.ecdfplot(single_step_error, c='blue', ax=ax, label='Single Step Error')
sns.ecdfplot(data_norm, c='green', ax=ax, label='Distribution')
ax.legend(loc='best');

# %% [markdown]
# ### **Student T Distribution**

# %%
kstest(single_step_error, stats.t.cdf, args=(5,mean,sigma), N=len(single_step_error))
# Out:
# KstestResult(statistic=0.0729848493160295, pvalue=1.31525420608005e-40)

# %%
_, ax = plt.subplots(1,1,figsize=(22,8))
probplot(single_step_error, dist=stats.t, sparams=(5,single_step_error.mean(),single_step_error.std()), plot=ax);

# %%
data_norm = stats.t.rvs(12, mean, sigma, size=len(single_step_error))
_, ax = plt.subplots(1,1,figsize=(22,8))
sns.ecdfplot(single_step_error, c='blue', ax=ax, label='Single Step Error')
sns.ecdfplot(data_norm, c='green', ax=ax, label='Distribution')
ax.legend(loc='best');

# %% [markdown]
# # Multi-Step Predictions

# %%
def sample_iter_distribution(predictions):
    gm = tfd.MixtureSameFamily(
        mixture_distribution=tfd.Categorical(probs=predictions[:,2,:]),
        components_distribution=tfd.Normal(
            loc=predictions[:,0,:],       
            scale=predictions[:,1,:]
        )
    )
    arr = tf.transpose(gm.sample(sample_shape=(1000))).numpy()
    predictions = np.stack([np.percentile(arr, 10, axis=-1), arr.mean(axis=-1), np.percentile(arr, 90, axis=-1)], axis=-1)
    return predictions

# %%
forecast_length = y_forecast.shape[1]
forecast_historical_series,forecast_historical_covariates,forecast_future_covariates=np.copy(X_forecast[0]),np.copy(X_forecast[1]),np.copy(X_forecast[2])
forecasts = []
for step in range(forecast_length):
    future_covaraites = forecast_future_covariates[:, step:step+1, :]
    predictions = forecaster.predict((forecast_historical_series,forecast_historical_covariates,future_covaraites))
    predictions = sample_iter_distribution(predictions)
    forecasts.append(predictions)
    # series
    forecast_historical_series = forecast_historical_series[:,1:,:]
    forecast_historical_series = np.squeeze(forecast_historical_series, axis=-1)
    forecast_historical_series = np.concatenate([forecast_historical_series,predictions[:,1:2]], axis=-1)
    forecast_historical_series = np.expand_dims(forecast_historical_series, -1)
    # covariates
    forecast_historical_covariates = forecast_historical_covariates[:,1:,:]
    forecast_historical_covariates = np.concatenate([forecast_historical_covariates,future_covaraites], axis=-2)

forecasts = np.stack(forecasts, axis=1)
forecasts.shape, forecast_dates.shape
# Out:
# 271/271 [==============================] - 6s 23ms/step
# 271/271 [==============================] - 6s 23ms/step
# 271/271 [==============================] - 6s 23ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 7s 24ms/step
# 271/271 [==============================] - 7s 24ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 6s 23ms/step
# 271/271 [==============================] - 7s 24ms/step
# 271/271 [==============================] - 6s 23ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 7s 24ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 6s 23ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 6s 24ms/step
# 271/271 [==============================] - 7s 24ms/step
# 271/271 [==============================] - 7s 24ms/step
# 271/271 [==============================] - 7s 24ms/step
# 271/271 [==============================] - 6s 24ms/step
# ((8670, 24, 3), (8670, 24))

# %%
real_forecasts = (forecasts * data_features[1]) + data_features[0]
actuals = (y_forecast * data_features[1]) + data_features[0]
errors = np.abs(real_forecasts[:,:,1] - actuals)

matrix_dates = []
error_matrix = np.full((forecast_dates.shape[0]+forecast_dates.shape[1]-1,forecast_dates.shape[1]), np.nan)
for idx in range(forecast_dates.shape[0]):
    matrix_dates.append(forecast_dates[idx,0])
    for step_idx in range(forecast_dates.shape[1]):
        error_matrix[idx+step_idx, step_idx] = errors[idx,step_idx]
        if(idx == forecast_dates.shape[0]-1 and step_idx > 0):
            matrix_dates.append(forecast_dates[idx, step_idx])

_, ax = plt.subplots(1,1,figsize=(22,12))
sns.heatmap(error_matrix)
ax.set_title('Heatmap of Absolute Errors', size=22)
ax.set_ylabel('Steps From the Begining of the Test Set Start', size=16)
ax.set_xlabel('Steps Forward in Forecast', size=16)
ax.set_yticklabels([]);

# %%
step_errors = np.nanmean(error_matrix, axis=0)
_, ax = plt.subplots(1,1,figsize=(22,12))
ax.set_title('Mean Absolute Error Per Step Ahead', size=20)
ax.set_xlabel('Steps Ahead', size=16)
ax.set_ylabel('Mean Absolute Error', size=16)
ax.plot(np.arange(len(step_errors)), step_errors, linewidth=3, alpha=0.8);

# %% [markdown]
# ## **Display Forecasts at a Number of Points**

# %%
sample_points = np.linspace(start=0, stop=forecasts.shape[0]-1, num=8).astype(int)
CONF_INTERVAL = 80
for sample_point in sample_points:
    _, ax = plt.subplots(1,1,figsize=(22,12))
    ax.set_title(f"Forecast Begining on {forecast_dates[sample_point,0]}", fontdict={'size':20})
    ax.set_ylabel("Water Level", fontdict={'size':16})
    ax.set_xlabel("Date", fontdict={'size':16})
    ax.plot(forecast_dates[sample_point,:], real_forecasts[sample_point,:,1], 'red', label='Forecast', alpha=0.5, linewidth=3, linestyle='dashed')
    ax.fill_between(forecast_dates[sample_point,:], real_forecasts[sample_point,:,0], real_forecasts[sample_point,:,2], color='red', label=f'{CONF_INTERVAL*100:.0f}% Conf Interval', alpha=0.25)
    ax.plot(forecast_dates[sample_point,:], actuals[sample_point,:], 'mediumblue', label='Actuals', alpha=0.5, linewidth=3)
    # get the actuals
    historical_actuals = (forecast_historical_series[sample_point,:] * data_features[1]) + data_features[0]
    ax.plot(forecast_historical_dates[sample_point,:], historical_actuals, 'grey', label='Historical Actuals', alpha=0.8, linewidth=3)
    ax.legend(loc='best')
    plt.show()
